# %%
from selenium import webdriver
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

browser=webdriver.Chrome(executable_path='C:\webdriver\chromedriver.exe')
browser.get('https://dev.to/')
#time.sleep(5)
#control_loading=20
#while control_loading>0:
    #browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    #time.sleep(3)
    #control_loading-1

try:
    article_titles=browser.find_elements(By.CLASS_NAME,'content')
    try:
        for at in article_titles:
            print(at)
    except Exception as e:
            print('Error reteriving article titles')
            
except Exception as e:
    print("Main error in searching particular element")
    print(str(e))
print(len(article_titles))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="ed9aa4a2-3ef8-4939-baed-62c9225bec81")>
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="1aeb6336-7563-40fd-80b4-ee73ae745718")>
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="5faf31e5-68b0-4a8b-84bf-6326f7592323")>
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="fe3914f3-7448-4fa5-9dd6-efc45c0bc916")>
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="7a862996-d04e-425c-b923-383fb913bc97")>
# <selenium.webdriver.remote.webelement.WebElement (session="dd333c97b1b7149e22c50382f3c39d22", element="25322909-3f1b-44c8-a30a-5bd3cec444ec")>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome(executable_path="C:\webdriver\chromedriver.exe")
driver.get('https://dev.to/search?q=books')
time.sleep(5)

try:
    article_titles=driver.find_elements_by_xpath('//a[@class="small-pic-link-wrapper index-article-link"]')
    try:
        for at in article_titles:
            print(at.text+'\n')
    except Exception as e:
            print('Error reteriving article titles')
            
except Exception as e:
    print("Main error in searching particular element")
    print(str(e))
print(len(article_titles))
# Out:
# 29 Must Read Books For Programmers
# …These are my "must read" programming books. They are universally applicable: you'll benefit from reading them regardless of…
#
# The 25 most recommended programming books of all-time.
# …This article is a follow up of the one I did about the the most recommended startup books of…
#
# 20 Most-Recommended Books for Software Developers
# …start to finish to understand the scope of the book's lessons. The next section, the bulk of the…
#
# Top 10 Free Books and Courses to learn Data Structure and Algorithms in 2020
# …right place. In the past, I have shared some books, tutorials, and interview questions on algorithms and data structure…
#
# 8 books every junior developer should read
# …on Twitter. Of course, seniors should also read these books, but most probably they already read at least a…
#
# 10 Best Books to Learn Data Structure and Algorithms in Java, Python, C, and C++
# ...

# %%
driver=webdriver.Chrome(executable_path="C:\webdriver\chromedriver.exe")
driver.get('https://dev.to/search?q=books')
time.sleep(5)

article_titles=driver.find_elements_by_xpath('//a[@class="small-pic-link-wrapper index-article-link"]')
article_titles[0].click
link_text_list=driver.find_elements(By.TAG_NAME,'a')
for text in link_text_list:
    print(text.text+'\n')
# Out:
# WRITE A POST
#
#
#
#
#
#
#
#
#
#
#
#
#
# POSTS
#
# PODCASTS
#
# PEOPLE
#
# ONLY MY POSTS
#
#
#
# 29 Must Read Books For Programmers
# …These are my "must read" programming books. They are universally applicable: you'll benefit from reading them regardless of…
#
# Blaine Osepchuk・Nov 14 '18
#
# #career
#
# #productivity
#
# #learning
#
# #effectiveness
#
# 94
#
# 2594
#
# 7 min read
#
#
#
# The 25 most recommended programming books of all-time.
# …This article is a follow up of the one I did about the the most recommended startup books of…
#
# Pierre ・Feb 18
#
# #books
#
# #beginners
#
# #career
#
# #programming
#
# 40
#
# 2028
#
# 19 min read
#
#
#
# 20 Most-Recommended Books for Software Developers
# …start to finish to understand the scope of the book's lessons. The next section, the bulk of the…
#
# Andrew (he/him)・Oct 19 '19
#
# #books
#
# #career
#
# #beginners
#
# 34
#
# 1896
#
# 19 min read
#
#
#
# Top 10 Free Books and Courses to learn Data Structure and Algorithms in 2020
# ...

# %%
raw_data=[]
clean_data=[]

# %%
#book_list start here
#1
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request


books=" "
book_list=[]
### Define getLinks Class
url="https://dev.to/bosepchuk/29-must-read-programming-books-2n45"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    #books=books+link.get_text()
    book_list.append(link.get_text())


#print(bsObj.findall('a',attrs={'class':'small-pic-link-wrapper index-article-link'}))
# Out:
# blog
#
#
# So Good They Can't Ignore You
#
#
# The Power of Habit: Why We Do What We Do in Life and Business
# The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time
# Badass: Making Users Awesome
# YouTube summary
#
#
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change
# The Effective Executive: The Definitive Guide to Getting the Right Things Done
# Great at Work: How Top Performers Do Less, Work Better, and Achieve More
# The Checklist Manifesto: How to Get Things Right
#
#
# The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact
# The Pragmatic Programmer: From Journeyman to Master
#
#
# Code Complete: A Practical Handbook of Software Construction, Second Edition
# Clean Code: A Handbook of Agile Software Craftsmanship
# Code Simplicity: The Fundamentals of Software
#
#
# ...

# %%
for raw_book in book_list:
    raw_data.append(raw_book)

# %%
#1
#print(book_list)
for book in book_list:
    if book == '\n':
        book_list.remove(book)
book_list.remove(book_list[0])
print(len(book_list))
print(book_list)
# Out:
# 33
# ...

# %%
#2
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

url="https://dev.to/awwsmm/20-most-recommended-books-for-software-developers-5578"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    book_list.append(link.get_text())
# Out:
# Russian Proverb
# a single Excel workbook on GitHub
#
#
#
# Patterns of Enterprise Application Architecture
#
#
#
#
# Amazon.com
#
#
#
# Clean Architecture: A Craftsman's Guide to Software Structure and Design
#
#
#
#
# Amazon.com
#
#
#
# The Art of Computer Programming
#
#
#
#
# Amazon.com
#
#
#
# CODE: The Hidden Language of Computer Hardware and Software
#
#
#
#
# Amazon.com
#
#
#
# Agile Software Development: Principles, Patterns, and Practices
#
#
#
#
# Amazon.com
#
#
#
# Introduction to Algorithms
#
#
#
#
# Amazon.com
#
#
#
# Head First Design Patterns: A Brain-Friendly Guide
#
#
#
#
# Amazon.com
#
#
#
# Cracking the Coding Interview: 189 Programming Questions and Solutions
#
#
#
#
# Amazon.com
#
#
#
# Don't Make Me Think: A Common Sense Approach to Web Usability
#
#
#
#
# Wikipedia
#
#
#
# The Clean Coder: A Code of Conduct for Professional Programmers
#
#
#
#
# Amazon.com
#
#
#
# Soft Skills: The Software Developer's Life Manual
#
#
#
#
# Amazon.com
#
#
#
# ...

# %%
for raw_book in book_list:
    raw_data.append(raw_book)

# %%
#2
#book_list[:]=[]
#print(book_list)
for book in book_list:
    if book == '\n':
        book_list.remove(book)
for book in book_list:
    if book == 'Amazon.com':
        book_list.remove(book)
        
for book in book_list:
    if book == '':
        book_list.remove(book)

#print((book_list[33:]))
print(len(book_list))
# Out:
# 82

# %%
#3
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

url="https://dev.to/daolf/the-25-most-recommended-programming-books-of-all-time-5fel"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    book_list.append(link.get_text())
# Out:
# the most recommended startup books of all-time
# results
# full results
#
#
#
#
#
# repo
#
#
#
#
# Continuous Delivery
#
# Amazon.com
#
#
# Algorithms
#
# Amazon.com
#
#
# The Self-Taught Programmer
#
# Amazon.com
#
#
# Rapid Development
#
# Amazon.com
#
#
# Coders at Work
#
# Amazon.com
#
#
# Domain-Driven Design
#
# Amazon.com
#
#
# The Art of Computer Programming
#
# Amazon.com
#
#
# Structure and Interpretation of Computer Programs
#
# Amazon.com
#
#
# Patterns of Enterprise Application Architecture
#
# Amazon.com
#
#
# Programming Pearls
#
# Amazon.com
#
#
# Peopleware
#
# Amazon.com
#
#
# Introduction to Algorithms
#
# Amazon.com
#
#
# Code
#
# Amazon.com
#
#
# Don't Make Me Think
#
# Amazon.com
#
#
# Soft Skills
#
# Amazon.com
#
#
# Cracking the Coding Interview
#
# Amazon.com
#
#
# Design Patterns
#
# Amazon.com
#
#
# Working Effectively with Legacy Code
#
# Amazon.com
#
#
# The Clean Coder
#
# Amazon.com
#
#
# The Mythical Man-Month
#
# Amazon.com
#
#
# ...

# %%
for raw_book in book_list:
    raw_data.append(raw_book)

# %%
#3
#print(book_list[62:])
for book in book_list:
    if book == '\n':
        book_list.remove(book)
        
for book in book_list:
    if book == '\n\n':
        book_list.remove(book)
        
for book in book_list:
    if book == 'Amazon.com':
        book_list.remove(book)
        
for book in book_list:
    if book == '':
        book_list.remove(book)
print(book_list[62:])
# Out:
# ['\n', 'Clean Code: A Handbook of Agile Software Craftsmanship', '\n', '\n', 'Dev.To', 'The Tweeter', 'buy me a cup of coffee']

# %%
#3
print(len(book_list))
# Out:
# 69

# %%
#4
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

url="https://dev.to/sandordargo/8-books-every-junior-developer-should-read--4p5h"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    book_list.append(link.get_text())
# Out:
# blog
# sign up to my newsletter
# follow me on Twitter
# Ryan Holiday
#
#
# Code Complete by Steve McConnell
#
#
# The Software Craftsman: Professionalism, Pragmatism, Pride by Sandro Mancuso
#
#
# Clean Code: A Handbook of Agile Software Craftsmanship
# Uncle Bob Martin
#
#
# Growing Object-Oriented Software, Guided by Tests by Steve Freeman
#
#
# The Clean Coder by Uncle Bob Martin
# Uncle Bob
#
#
# Refactoring - Improving the Design of Existing Code by Martin Fowler
#
#
# Working Effectively with Legacy Code by Michael Feathers
#
#
# The Complete Software Developer's Career Guide by John Sonmez

# %%
for raw_book in book_list:
    raw_data.append(raw_book)

# %%
#4
#book_list
for book in book_list:
    if book == '\n':
        book_list.remove(book)
print(len(book_list))
# Out:
# 109

# %%
#5
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list=[]
url="https://dev.to/erikwhiting88/5-great-programming-books-rarely-mentioned-in-great-programming-books-articles-4l5j"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('h1'):
    print(link.get_text())
    temp_list.append(link.get_text())
# Out:
#   The Usual Suspects
#
#
#
#
#   1. Practical Object-Oriented Design: An Agile Primer Using Ruby
#
#
#
#
#   2. Test-Driven Development with Python (aka, Obey the Testing Goat)
#
#
#
#
#   3. Functional Programming in C#
#
#
#
#
#   4. 24 Deadly Sins of Software Security: Programming Flaws and How to Fix Them
#
#
#
#
#   5. Agile Testing: A Practical Guide for Testers and Agile Teams
#
#
#
#
#   Conclusion

# %%
for raw_book in temp_list:
    raw_data.append(raw_book)

# %%
#5
#print(len(temp_list))
new_temp_list=[]
#temp_list.remove(temp_list[0])
#temp_list.remove(temp_list[])
#temp_list.remobe(temp_list[0])
for book in temp_list:
    book=book[7:-1]
    new_temp_list.append(book)
    
new_temp_list.remove(new_temp_list[0])
print(new_temp_list)
# Out:
# [' Practical Object-Oriented Design: An Agile Primer Using Ruby', ' Test-Driven Development with Python (aka, Obey the Testing Goat)', ' Functional Programming in C#', ' 24 Deadly Sins of Software Security: Programming Flaws and How to Fix Them', ' Agile Testing: A Practical Guide for Testers and Agile Teams', 'nclusion']

# %%
#5
for book in new_temp_list:
    book_list.append(book)
print(len(book_list))
print(book_list)
# Out:
# 115
# ...

# %%
#6
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list1=[]
url="https://dev.to/phillie/what-are-your-must-read-tech-books-for-2018-3cgp"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('strong'):
    print(link.get_text())
    temp_list1.append(link.get_text())
# Out:
# what are your must-read books about the tech industry (in general), computer science, programming, web dev, software engineering, digital culture and so forth?
# Software & Web Dev
# Progressive Web Apps
# Camel in Action
# Programming Pearls
# Cracking the Coding Interview: 150 Programming Questions and Solutions
# Math
# A Mind for Numbers: How to Excel at Math and Science (Even If You Flunked Algebra)
# Tech Industry und The Digital & Information Age in General
# Chaos Monkeys: Inside the Silicon Valley money machine
# Weapons of Math Destruction
# Pax Technica
# The Innovators: How a Group of Hackers, Geniuses, and Geeks Created The Digital Revolution
# This Machine Kills Secrets
# The Open Organisation
# Superintelligence: Paths, Dangers, Strategies
# The Shallows: What the Internet is Doing to Our Brains
# The Master Switch: The Rise and Fall of Information Empires
# Data
# We Are Data: Algorithms and The Making of Our Digital Selves
# Being Digital Citizens
# ...

# %%
for raw_book in temp_list1:
    raw_data.append(raw_book)

# %%
#6
#print(temp_list1)
#print(temp_list1[2:6])
for book in temp_list1[2:6]:
    book_list.append(book)
    
print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#7
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list2=[]
url="https://dev.to/pluralsight/the-top-10-books-on-devops-you-need-to-read-45m2"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('h2'):
    print(link.get_text())
    temp_list2.append(link.get_text())
# Out:
#   1. The DevOps Handbook
#
#
#
#
#   2. The Phoenix Project
#
#
#
#
#   3. Accelerate: The Science of Lean Software and DevOps
#
#
#
#
#   4. Continuous Delivery: Reliable Software Releases through Build, Test, and Deployment Automation
#
#
#
#
#   5. Effective DevOps
#
#
#
#
#   6. Measure What Matters
#
#
#
#
#   7. Site Reliability Engineering
#
#
#
#
#   8. Site Reliability Workbook
#
#
#
#
#   9. Infrastructure as Code
#
#
#
#
#   10. The Goal

# %%
for raw_book in temp_list2:
    raw_data.append(raw_book)

# %%
#7
#print(temp_list2)
new_temp_list1=[]
for book in temp_list2:
    book=book[7:-1]
    new_temp_list1.append(book)
print(new_temp_list1)
# Out:
# [' The DevOps Handbook', ' The Phoenix Project', ' Accelerate: The Science of Lean Software and DevOps', ' Continuous Delivery: Reliable Software Releases through Build, Test, and Deployment Automation', ' Effective DevOps', ' Measure What Matters', ' Site Reliability Engineering', ' Site Reliability Workbook', ' Infrastructure as Code', '. The Goal']

# %%
#7
for book in new_temp_list1:
    book_list.append(book)
print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#8
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list2=[]

url="https://dev.to/lpasqualis/11-books-all-software-engineers-must-read"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('h2'):
    print(link.get_text())
    temp_list2.append(link.get_text())
# Out:
#   Extreme Ownership: How U.S. Navy SEALs Lead and Win
#
#
#
#
#   Scrum: The Art of Doing Twice the Work in Half the Time
#
#
#
#
#   The 5 Second Rule
#
#
#
#
#   Steve Jobs
#
#
#
#
#   Quiet: The Power of Introverts in a World That Can't Stop Talking
#
#
#
#
#   The Practicing Mind: Developing Focus and Discipline in Your Life – Master Any Skill or Challenge by Learning to Love the Process
#
#
#
#
#   Algorithms to Live By: The Computer Science of Human Decisions
#
#
#
#
#   Simple Rules: How to Thrive in a Complex World
#
#
#
#
#   Zero to One: Notes on Startups, or How to Build the Future
#
#
#
#
#   Make It Stick: The Science of Successful Learning
#
#
#
#
#   The Innovators: How a Group of Hackers, Geniuses, and Geeks Created the Digital Revolution
#
#
#
#
#   The Tipping Point: How Little Things Can Make a Big Difference

# %%
for raw_book in temp_list2:
    raw_data.append(raw_book)

# %%
#8
#print(temp_list2)
new_temp_list2=[]
for book in temp_list2:
    book=book[3:-1]
    new_temp_list2.append(book)
    
print(new_temp_list2)
# Out:
# ['  Extreme Ownership: How U.S. Navy SEALs Lead and Win', '  Scrum: The Art of Doing Twice the Work in Half the Time', '  The 5 Second Rule', '  Steve Jobs', "  Quiet: The Power of Introverts in a World That Can't Stop Talking", '  The Practicing Mind: Developing Focus and Discipline in Your Life – Master Any Skill or Challenge by Learning to Love the Process', '  Algorithms to Live By: The Computer Science of Human Decisions', '  Simple Rules: How to Thrive in a Complex World', '  Zero to One: Notes on Startups, or How to Build the Future', '  Make It Stick: The Science of Successful Learning', '  The Innovators: How a Group of Hackers, Geniuses, and Geeks Created the Digital Revolution', '  The Tipping Point: How Little Things Can Make a Big Difference']

# %%
#8
for book in new_temp_list2:
    book_list.append(book)

print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#9
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list3=[]

url="https://dev.to/jacobherrington/the-best-books-for-new-devs--bonus-twitter-thread-54ag"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    temp_list3.append(link.get_text())
# Out:
# @kyleshevlin
# @jlengstorf
# @jhooks
# @kentcdodds
# @wesbos
# @stolinski
# @shanselman
# @SachaGreif
#
#
#
#
#
#
#
#
#
# Code: The Hidden Language of Computer Hardware and Software
# Clean Code
# Cracking the Coding Interview
# Code Complete
# How to Win Friends and Influence People

# %%
for raw_book in temp_list3:
    raw_data.append(raw_book)

# %%
#9
#print(temp_list3)
new_temp_list3=[]
for book in temp_list3[11:]:
    new_temp_list3.append(book)
    
print(new_temp_list3)
# Out:
# ['Code: The Hidden Language of Computer Hardware and Software', 'Clean Code', 'Cracking the Coding Interview', 'Code Complete', 'How to Win Friends and Influence People']

# %%
#9
for book in new_temp_list3:
    book_list.append(book)

print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#10
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list4=[]

url="https://dev.to/pandiyancool/5-books-about-programming-you-should-read-18if"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('h2'):
    print(link.get_text())
    temp_list4.append(link.get_text())
# Out:
#   The Clean Coder: A Code of Conduct for Professional Programmers
#
#
#
#
#   The Art of Readable Code
#
#
#
#
#   Don’t Make Me Think, Revisited: A Common Sense Approach to Web Usability
#
#
#
#
#   JavaScript: The Good Parts
#
#
#
#
#   Even Faster Web Sites

# %%
for raw_book in temp_list4:
    raw_data.append(raw_book)

# %%
#10
#print(temp_list4)
new_temp_list4=[]
for book in temp_list4:
    book=book[5:-1]
    new_temp_list4.append(book)

# %%
#10
for book in new_temp_list4:
    book_list.append(book)

print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#11
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list5=[]

url="https://dev.to/patferraggi/5-books-every-developer-should-read-and-some-extras-377n"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('a'):
    print(link.get_text())
    temp_list5.append(link.get_text())
# Out:
# The Developer's Dungeon
# here!
#
#
# Clean Code: A Handbook of Agile Software Craftsmanship (Robert C. Martin)
#
#
#
# The Pragmatic Programmer, your journey to mastery (Dave Thomas and Andrew Hunt)
#
#
#
# The Clean Coder: A Code of Conduct for Professional Programmers (Robert C. Martin)
#
#
#
# Working Effectively With Legacy Code (Michael Feathers)
#
#
#
# Test Driven Development By Example (Kent Beck)
#
# Refactoring: Improving the Design of Existing Code (Martin Fowler)
# Adaptive Code: Agile coding with design patterns and SOLID principles (Gary McLean Hall)
# Clean Architecture: A Craftsman's Guide to Software Structure and Design
#  (Robert C. Martin)
# Structure and Interpretation of Computer Programs (Harold Abelson and
# Gerald Jay Sussman
# with Julie Sussman)
# Design Patterns: Elements of Reusable Object-Oriented Software (Gang of Four)
# Head First Design Patterns: A Brain-Friendly Guide (Eric Freeman and Elisabeth Robson)

# %%
for raw_book in temp_list5:
    raw_data.append(raw_book)

# %%
#11
#print(temp_list5)
new_temp_list5=[]
for book in temp_list5:
    if book =='\n':
        temp_list5.remove(book)
        
for book in temp_list5[2:]:
    new_temp_list5.append(book)
    
print(new_temp_list5)
# Out:
# ['Clean Code: A Handbook of Agile Software Craftsmanship (Robert C. Martin)', '', 'The Pragmatic Programmer, your journey to mastery (Dave Thomas and Andrew Hunt)', '', 'The Clean Coder: A Code of Conduct for Professional Programmers (Robert C. Martin)', '', 'Working Effectively With Legacy Code (Michael Feathers)', '', 'Test Driven Development By Example (Kent Beck)', '', 'Refactoring: Improving the Design of Existing Code (Martin Fowler)', 'Adaptive Code: Agile coding with design patterns and SOLID principles (Gary McLean Hall)', "Clean Architecture: A Craftsman's Guide to Software Structure and Design \n (Robert C. Martin)", 'Structure and Interpretation of Computer Programs (Harold Abelson and\nGerald Jay Sussman\nwith Julie Sussman)', 'Design Patterns: Elements of Reusable Object-Oriented Software (Gang of Four)', 'Head First Design Patterns: A Brain-Friendly Guide (Eric Freeman and Elisabeth Robson)']

# %%
#11
for book in new_temp_list5:
    book_list.append(book)
    
print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#12
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list6=[]

url="https://dev.to/rommik/10-books-that-every-developer-must-read--28ia"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('td'):
    print(link.get_text())
    temp_list6.append(link.get_text())
# Out:
# The Clean Coder: A Code of Conduct for Professional Programmers by Robert C. Martin http://amzn.to/2EqFxlb
#
# Compared to Law, Medicine, Engineering, Accounting, Programming is a relatevely easy field to enter. There're countless success stories of self-thought programmers. This book introduces to what a Professional Programmer is. The author shows how to approach software development with honor, self-respect, and pride; work well and work clean; communicate and estimate faithfully; face difficult decisions with clarity and honesty; and understand that deep knowledge comes with a responsibility to act.
#
#
#
# Clean Code: A Handbook of Agile Software Craftsmanship by Robert C. Martin http://amzn.to/2ssThWJ
#
# ...

# %%
for raw_book in temp_list6:
    raw_data.append(raw_book)

# %%
#12
#print(temp_list6)
#print(temp_list6[10])

even=[1,4,7,10,13,16,19,22,25,28]
#print(temp_list6[28])

new_temp_list6=[]
new_temp_list6_=[]

for i in even:
    new_temp_list6.append(temp_list6[i])

#for i in even:
    #for book in temp_list6:
        #new_temp_list6.append(book[i])
for book in new_temp_list6:
    #print(book.find('http',-24,-1))
    book=book[:-24]
    new_temp_list6_.append(book)
    

#print(new_temp_list6)
for book in new_temp_list6_:
    print(book)
# Out:
# The Clean Coder: A Code of Conduct for Professional Programmers by Robert C. Martin
# Clean Code: A Handbook of Agile Software Craftsmanship by Robert C. Martin
# Clean Architecture: A Craftsman's Guide to Software Structure and Design by Robert C. Martin
# Head First Design Patterns: A Brain-Friendly Guide
# Peopleware: Productive Projects and Teams
# The Algorithm Design Manual by Steven S Skiena
# Agile Software Development, Principles, Patterns, and Practices by Robert C. Martin
# Working Effectively with Legacy Code by Michael Feathers
# Head First Object-Oriented Analysis and Design
# The Pragmatic Programmer: From Journeyman to Master by Andrew Hunt and David Thomas

# %%
#12
for book in new_temp_list6_:
    book_list.append(book)
print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
#13
#book_list ends here
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import re
import urllib.parse
import urllib.request

temp_list7=[]

url="https://dev.to/bosepchuk/4-books-guaranteed-to-make-you-a-better-programmer--2hj2"
headers = {}
headers['User-Agent'] = "Chrome/24.0.1312.27"

request = urllib.request.Request(url, headers = headers)
response = urllib.request.urlopen(request)
responseData = response.read()
    ### use urllib.request.urlopen to crawl wikipedia site with new links extracted iteratively
#html = urlopen("https://dev.to/search?q=books")
bsObj = BeautifulSoup(responseData,'html.parser')

#print(bsObj.prettify())
#print(bsObj.findAll('a',attrs={'class':"small-pic-link-wrapper index-article-link"}))   
for link in bsObj.find("div",{"id":"article-body"}).findAll('h3'):
    print(link.get_text())
    temp_list7.append(link.get_text())
# Out:
#   1. The Goal: A Process of Ongoing Improvement
#
#
#
#
#   2. It's Not Luck
#
#
#
#
#   3. Velocity: Combining Lean, Six Sigma and the Theory of Constraints to Achieve Breakthrough Performance
#
#
#
#
#   4. The Phoenix Project: A Novel about IT, DevOps, and Helping Your Business Win
#
#
#
#
#   How these novels are going to help you become a better programmer
#
#
#
#
#   Recommendations for reading
#
#
#
#
#   Takeaways

# %%
for raw_book in temp_list7:
    raw_data.append(raw_book)

# %%
#13
#print(temp_list7)
new_temp_list7=[]
for book in temp_list7[0:4]:
    book=book[7:-1]
    new_temp_list7.append(book)
    
print(new_temp_list7)
# Out:
# [' The Goal: A Process of Ongoing Improvement', " It's Not Luck", ' Velocity: Combining Lean, Six Sigma and the Theory of Constraints to Achieve Breakthrough Performance', ' The Phoenix Project: A Novel about IT, DevOps, and Helping Your Business Win']

# %%
#13
for book in new_temp_list7:
    book_list.append(book)
    
print(book_list)
# Out:
# ["So Good They Can't Ignore You", 'The Power of Habit: Why We Do What We Do in Life and Business', 'The Spirit of Kaizen: Creating Lasting Excellence One Small Step at a Time: Creating Lasting Excellence One Small Step at a Time', 'Badass: Making Users Awesome', 'YouTube summary', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'The Effective Executive: The Definitive Guide to Getting the Right Things Done', 'Great at Work: How Top Performers Do Less, Work Better, and Achieve More', 'The Checklist Manifesto: How to Get Things Right', 'The Effective Engineer: How to Leverage Your Efforts In Software Engineering to Make a Disproportionate and Meaningful Impact', 'The Pragmatic Programmer: From Journeyman to Master', 'Code Complete: A Practical Handbook of Software Construction, Second Edition', 'Clean Code: A Handbook of Agile Software Craftsmanship', 'Code Simplicity: The Fundamentals of Software', 'Facts and Fallacies of Software Engineering', 'Rapid D
# ...

# %%
book_list_lower=[]
for book in book_list:
    book_list_lower.append(book.lower())

print(book_list_lower)
print(len(book_list_lower))
# Out:
# ["so good they can't ignore you", 'the power of habit: why we do what we do in life and business', 'the spirit of kaizen: creating lasting excellence one small step at a time: creating lasting excellence one small step at a time', 'badass: making users awesome', 'youtube summary', 'the 7 habits of highly effective people: powerful lessons in personal change', 'the effective executive: the definitive guide to getting the right things done', 'great at work: how top performers do less, work better, and achieve more', 'the checklist manifesto: how to get things right', 'the effective engineer: how to leverage your efforts in software engineering to make a disproportionate and meaningful impact', 'the pragmatic programmer: from journeyman to master', 'code complete: a practical handbook of software construction, second edition', 'clean code: a handbook of agile software craftsmanship', 'code simplicity: the fundamentals of software', 'facts and fallacies of software engineering', 'rapid d
# ...

# %%
counts=dict()
for book_name in book_list_lower:
    if book_name.startswith("so good"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the power of habit"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the spirit of kaizen"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("badass"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the 7 habits"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the effective executive"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("great at work"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the checklist manifesto"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the effective engineer"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the pragmatic programmer"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("code complete"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("clean code"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("code simplicity"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("programming pearls"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("facts and fallacies"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("rapid development"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("making software"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("measure what matters"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("turn the ship around"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("scrum"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the lean startup"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the phoenix project"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the principles of product development flow"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("goldratt's theory "):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("starting to unit test"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("working effectively with unit tests"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("working effectively with legacy code"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("don't make me think"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("rocket surgery"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("patterns of enterprise application"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("clean architecture"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the art of computer programming"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("design patterns"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("code"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("agile software development"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("head first design patterns"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("introduction to algorithms"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("cracking the coding "):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the clean coder"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("soft skills"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("peopleware"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("programming pearls"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the mythical"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("refactoring"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("continuous delivery"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the self-taught programmer"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("coders at work"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("domain-driven design"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("structure and interpretation"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("growing object-oriented software"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the complete software developer's"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("practical object-oriented design"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("test-driven"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("agile testing"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("progressive web apps"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("camel in action"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the devops"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("accelerate"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("site reliability engineering"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("site reliability workbook"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("infrastructure as code"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the 5 second rule"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("quiet"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the practicing mind"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("algorithms to live"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("simple rules"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("zero to one"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("make It stick"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the innovators"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the tipping point"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("how to win"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the art of readable"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("even faster"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("adaptive code"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the algorithm design"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("the goal"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("tt's not luck"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
    elif book_name.startswith("velocity"):
        if book_name not in counts:
            counts[book_name]=1
        else:
                counts[book_name]=counts[book_name]+1
                
for cntKey in counts:
    print(cntKey,counts[cntKey])
# Out:
# so good they can't ignore you 1
# the power of habit: why we do what we do in life and business 1
# the spirit of kaizen: creating lasting excellence one small step at a time: creating lasting excellence one small step at a time 1
# badass: making users awesome 1
# the 7 habits of highly effective people: powerful lessons in personal change 1
# the effective executive: the definitive guide to getting the right things done 1
# great at work: how top performers do less, work better, and achieve more 1
# the checklist manifesto: how to get things right 1
# the effective engineer: how to leverage your efforts in software engineering to make a disproportionate and meaningful impact 1
# the pragmatic programmer: from journeyman to master 2
# code complete: a practical handbook of software construction, second edition 1
# clean code: a handbook of agile software craftsmanship 3
# code simplicity: the fundamentals of software 1
# facts and fallacies of software engineering 1
# ...

# %%
for cntKey in counts:
    control=counts[cntKey]
    if control>1:
        print(cntKey,counts[cntKey])
# Out:
# the pragmatic programmer: from journeyman to master 2
# clean code: a handbook of agile software craftsmanship 3
# rapid development: taming wild software schedules 2
# working effectively with legacy code 3
# patterns of enterprise application architecture 2
# the art of computer programming 2
# code: the hidden language of computer hardware and software 2
# introduction to algorithms 2
# head first design patterns: a brain-friendly guide 2
# the clean coder: a code of conduct for professional programmers 2
# peopleware: productive projects and teams 2
# programming pearls 3
# cracking the coding interview 2
# code complete 2
# clean code 2
# working effectively with legacy code by michael feathers 2

# %%
new_counts=dict()
for cntKey in counts:
    control=counts[cntKey]
    if control>1:
        new_counts[cntKey]=counts[cntKey];
    

print(new_counts)
# Out:
# {'the pragmatic programmer: from journeyman to master': 2, 'clean code: a handbook of agile software craftsmanship': 3, 'rapid development: taming wild software schedules': 2, 'working effectively with legacy code': 3, 'patterns of enterprise application architecture': 2, 'the art of computer programming': 2, 'code: the hidden language of computer hardware and software': 2, 'introduction to algorithms': 2, 'head first design patterns: a brain-friendly guide': 2, 'the clean coder: a code of conduct for professional programmers': 2, 'peopleware: productive projects and teams': 2, 'programming pearls': 3, 'cracking the coding interview': 2, 'code complete': 2, 'clean code': 2, 'working effectively with legacy code by michael feathers': 2}

# %%
import matplotlib.pyplot as plt

plt.bar(new_counts.keys(), new_counts.values(),color='g')
plt.xticks(rotation=90)
plt.show()

# %%
#print(raw_data)
rawdata_file=open("raw_data.txt","w+")
for data in raw_data:
    rawdata_file.write(data)
rawdata_file.close()

# %%
for clean_book in book_list_lower:
    clean_data.append(clean_book)
    
for book in clean_data:
    print(book)
# Out:
# so good they can't ignore you
# the power of habit: why we do what we do in life and business
# the spirit of kaizen: creating lasting excellence one small step at a time: creating lasting excellence one small step at a time
# badass: making users awesome
# youtube summary
# the 7 habits of highly effective people: powerful lessons in personal change
# the effective executive: the definitive guide to getting the right things done
# great at work: how top performers do less, work better, and achieve more
# the checklist manifesto: how to get things right
# the effective engineer: how to leverage your efforts in software engineering to make a disproportionate and meaningful impact
# the pragmatic programmer: from journeyman to master
# code complete: a practical handbook of software construction, second edition
# clean code: a handbook of agile software craftsmanship
# code simplicity: the fundamentals of software
# facts and fallacies of software engineering
# ...

# %%
cleandata_file=open("clean_data.txt","w+")
for data in clean_data:
    cleandata_file.write(data)

cleandata_file.close()
